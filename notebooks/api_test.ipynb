# %%
import requests

# %%
res = requests.get("https://api.openaq.org/v2/locations/2178", headers={"X-API-Key": "230e041c1b6118b3473ae70fe59697c6818d5ee921b03b3e97e6982305f3e8e6"})

# %%
res.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 2178,
#    'city': 'Albuquerque',
#    'name': 'Del Norte',
#    'entity': None,
#    'country': 'US',
#    'sources': None,
#    'isMobile': False,
#    'isAnalysis': None,
#    'parameters': [{'id': 7,
#      'unit': 'ppm',
#      'count': 46641,
#      'average': 0.008968450003273275,
#      'lastValue': 0.0005,
#      'parameter': 'no2',
#      'displayName': 'no2 ppm',
#      'lastUpdated': '2023-08-15T01:00:00+00:00',
#      'parameterId': 7,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
#      'manufacturers': None},
#     {'id': 2,
#      'unit': 'µg/m³',
#      'count': 47208,
#      'average': 5.987498383411672,
#      'lastValue': 3.3,
#      'parameter': 'pm25',
#      'displayName': 'pm25 µg/m³',
#      'lastUpdated': '2023-08-15T01:00:00+00:00',
#      'parameterId': 2,
#      'firstUpdated': '2016-03-06T19:00:00+00:00',
# ...
